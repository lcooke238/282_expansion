# %% [markdown]
# # Archive

# %% [markdown]
# ## Imports and Requirements

# %%
# install necessary requirements
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: ray<2.4,>=2.3 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: sacred>=0.8.2 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (0.8.4)
# Requirement already satisfied: torch>=1.10.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: minigrid>=2.2 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (2.2.1)
# Requirement already satisfied: numpy==1.20.3 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (1.20.3)
# Requirement already satisfied: autorom>=0.4.2 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from autorom[accept-rom-license]>=0.4.2->-r requirements.txt (line 7)) (0.6.1)
# Requirement already satisfied: GPUtil>=1.4.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (1.4.0)
# Requirement already satisfied: procgen>=0.10.7 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (0.10.7)
# Requirement already satisfied: torchvision>=0.11.1 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (0.16.0)
# Requirement already satisfied: tensorflow-probability in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (0.22.1)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (4.66.1)
# Requirement already satisfied: gymnasium[atari] in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.26.3)
# Requirement already satisfied: attrs in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: click>=7.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (8.1.7)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (3.13.1)
# Requirement already satisfied: jsonschema in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (4.19.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (1.0.7)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (4.25.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: aiosignal in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: frozenlist in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: requests in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: virtualenv>=20.0.24 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (20.24.6)
# Requirement already satisfied: grpcio<=1.49.1,>=1.32.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (1.49.1)
# Requirement already satisfied: docopt<1.0,>=0.3 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from sacred>=0.8.2->-r requirements.txt (line 2)) (0.6.2)
# Requirement already satisfied: jsonpickle>=1.2 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from sacred>=0.8.2->-r requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: munch<3.0,>=2.5 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from sacred>=0.8.2->-r requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: wrapt<2.0,>=1.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from sacred>=0.8.2->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: py-cpuinfo>=4.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from sacred>=0.8.2->-r requirements.txt (line 2)) (9.0.0)
# Requirement already satisfied: colorama>=0.4 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from sacred>=0.8.2->-r requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: packaging>=18.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from sacred>=0.8.2->-r requirements.txt (line 2)) (23.2)
# Requirement already satisfied: GitPython in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from sacred>=0.8.2->-r requirements.txt (line 2)) (3.1.40)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from torch>=1.10.0->-r requirements.txt (line 3)) (4.8.0)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from torch>=1.10.0->-r requirements.txt (line 3)) (1.12)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from torch>=1.10.0->-r requirements.txt (line 3)) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from torch>=1.10.0->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from torch>=1.10.0->-r requirements.txt (line 3)) (2023.10.0)
# Requirement already satisfied: pygame>=2.2.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from minigrid>=2.2->-r requirements.txt (line 4)) (2.5.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from gymnasium[atari]->-r requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: gymnasium-notices>=0.0.1 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from gymnasium[atari]->-r requirements.txt (line 5)) (0.0.1)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from gymnasium[atari]->-r requirements.txt (line 5)) (6.8.0)
# Requirement already satisfied: ale-py~=0.8.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from gymnasium[atari]->-r requirements.txt (line 5)) (0.8.1)
# Requirement already satisfied: gym<1.0.0,>=0.15.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from procgen>=0.10.7->-r requirements.txt (line 9)) (0.26.2)
# Requirement already satisfied: gym3<1.0.0,>=0.3.3 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from procgen>=0.10.7->-r requirements.txt (line 9)) (0.3.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from torchvision>=0.11.1->-r requirements.txt (line 10)) (10.0.1)
# Requirement already satisfied: absl-py in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from tensorflow-probability->-r requirements.txt (line 11)) (2.0.0)
# Requirement already satisfied: six>=1.10.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from tensorflow-probability->-r requirements.txt (line 11)) (1.16.0)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from tensorflow-probability->-r requirements.txt (line 11)) (5.1.1)
# Requirement already satisfied: gast>=0.3.2 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from tensorflow-probability->-r requirements.txt (line 11)) (0.5.4)
# Requirement already satisfied: dm-tree in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from tensorflow-probability->-r requirements.txt (line 11)) (0.1.8)
# Requirement already satisfied: AutoROM.accept-rom-license in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from autorom[accept-rom-license]>=0.4.2->-r requirements.txt (line 7)) (0.6.1)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (2.0.3)
# Requirement already satisfied: tabulate in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: tensorboardX>=1.9 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (2.6.2.2)
# Requirement already satisfied: lz4 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (4.3.2)
# Requirement already satisfied: scikit-image in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (0.19.3)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (1.10.1)
# Requirement already satisfied: typer in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: rich in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (13.6.0)
# Requirement already satisfied: importlib-resources in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from ale-py~=0.8.0->gymnasium[atari]->-r requirements.txt (line 5)) (6.1.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from gym<1.0.0,>=0.15.0->procgen>=0.10.7->-r requirements.txt (line 9)) (0.0.8)
# Requirement already satisfied: cffi<2.0.0,>=1.13.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from gym3<1.0.0,>=0.3.3->procgen>=0.10.7->-r requirements.txt (line 9)) (1.16.0)
# Requirement already satisfied: imageio<3.0.0,>=2.6.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from gym3<1.0.0,>=0.3.3->procgen>=0.10.7->-r requirements.txt (line 9)) (2.32.0)
# Requirement already satisfied: imageio-ffmpeg<0.4.0,>=0.3.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from gym3<1.0.0,>=0.3.3->procgen>=0.10.7->-r requirements.txt (line 9)) (0.3.0)
# Requirement already satisfied: glfw<2.0.0,>=1.8.6 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from gym3<1.0.0,>=0.3.3->procgen>=0.10.7->-r requirements.txt (line 9)) (1.12.0)
# Requirement already satisfied: moderngl<6.0.0,>=5.5.4 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from gym3<1.0.0,>=0.3.3->procgen>=0.10.7->-r requirements.txt (line 9)) (5.8.2)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from importlib-metadata>=4.8.0->gymnasium[atari]->-r requirements.txt (line 5)) (3.17.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from virtualenv>=20.0.24->ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (0.3.7)
# Requirement already satisfied: platformdirs<4,>=3.9.1 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from virtualenv>=20.0.24->ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (3.11.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from GitPython->sacred>=0.8.2->-r requirements.txt (line 2)) (4.0.11)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from jinja2->torch>=1.10.0->-r requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from jsonschema->ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from jsonschema->ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from jsonschema->ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (0.12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from pandas->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from pandas->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from pandas->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from requests->ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from requests->ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from requests->ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from requests->ray<2.4,>=2.3->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from rich->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from rich->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (2.16.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from scikit-image->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from scikit-image->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from sympy->torch>=1.10.0->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from cffi<2.0.0,>=1.13.0->gym3<1.0.0,>=0.3.3->procgen>=0.10.7->-r requirements.txt (line 9)) (2.21)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython->sacred>=0.8.2->-r requirements.txt (line 2)) (5.0.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->ray[rllib]<2.4,>=2.3->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: glcontext<3,>=2.3.6 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from moderngl<6.0.0,>=5.5.4->gym3<1.0.0,>=0.3.3->procgen>=0.10.7->-r requirements.txt (line 9)) (2.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Dataset

# %%
# get BRIDGE dataset setup after download
import os

path = os.path.join(os.getcwd(), "../data/bridge_dataset.zip")
# !unzip $path
# Out:
# Archive:  /Users/laurenc/Documents/GitHub/282_expansion/scripts/../data/bridge_dataset.zip
#   inflating: bridge_dataset/README.md
#   inflating: bridge_dataset/summary.csv
#    creating: bridge_dataset/mdps_with_reward_shaping/
#    creating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-KeyCorridorS3R3-PickupShaped-v0/
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-KeyCorridorS3R3-PickupShaped-v0/gorp_3.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-KeyCorridorS3R3-PickupShaped-v0/gorp_5.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-KeyCorridorS3R3-PickupShaped-v0/gorp_2.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-KeyCorridorS3R3-PickupShaped-v0/gorp_4.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-KeyCorridorS3R3-PickupShaped-v0/consolidated_gorp_bounds.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-KeyCorridorS3R3-PickupShaped-v0/consolidated.npz
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-KeyCorridorS3R3-PickupShaped-v0/consolidated_analyzed.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-KeyCorridorS3R3-PickupShaped-v0/gorp_1.json
#    creating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-Empty-5x5-DistanceShaped-v0/
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-Empty-5x5-DistanceShaped-v0/gorp_3.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-Empty-5x5-DistanceShaped-v0/gorp_6.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-Empty-5x5-DistanceShaped-v0/gorp_5.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-Empty-5x5-DistanceShaped-v0/gorp_2.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-Empty-5x5-DistanceShaped-v0/gorp_4.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-Empty-5x5-DistanceShaped-v0/gorp_8.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-Empty-5x5-DistanceShaped-v0/consolidated_gorp_bounds.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-Empty-5x5-DistanceShaped-v0/consolidated.npz
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-Empty-5x5-DistanceShaped-v0/gorp_7.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-Empty-5x5-DistanceShaped-v0/consolidated_analyzed.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-Empty-5x5-DistanceShaped-v0/gorp_1.json
#    creating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-KeyCorridorS4R3-OpenDoorsPickupShaped-v0/
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-KeyCorridorS4R3-OpenDoorsPickupShaped-v0/gorp_3.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-KeyCorridorS4R3-OpenDoorsPickupShaped-v0/gorp_5.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-KeyCorridorS4R3-OpenDoorsPickupShaped-v0/gorp_2.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-KeyCorridorS4R3-OpenDoorsPickupShaped-v0/gorp_4.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-KeyCorridorS4R3-OpenDoorsPickupShaped-v0/consolidated_gorp_bounds.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-KeyCorridorS4R3-OpenDoorsPickupShaped-v0/consolidated.npz
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-KeyCorridorS4R3-OpenDoorsPickupShaped-v0/consolidated_analyzed.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-KeyCorridorS4R3-OpenDoorsPickupShaped-v0/gorp_1.json
#    creating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-MultiRoom-N2-S4-OpenDoorsShaped-v0/
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-MultiRoom-N2-S4-OpenDoorsShaped-v0/gorp_3.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-MultiRoom-N2-S4-OpenDoorsShaped-v0/gorp_5.json
#   inflating: bridge_dataset/mdps_with_reward_shaping/MiniGrid-MultiRoom-N2-S4
v0/consolidated_analyzed.json
#   inflating: bridge_dataset/mdps/MiniGrid-SimpleCrossingS9N3-v0/gorp_1.json
#    creating: bridge_dataset/mdps/assault_10_fs30/
#   inflating: bridge_dataset/mdps/assault_10_fs30/gorp_3.json
#   inflating: bridge_dataset/mdps/assault_10_fs30/gorp_6.json
#   inflating: bridge_dataset/mdps/assault_10_fs30/gorp_5.json
#   inflating: bridge_dataset/mdps/assault_10_fs30/gorp_2.json
#   inflating: bridge_dataset/mdps/assault_10_fs30/gorp_4.json
#   inflating: bridge_dataset/mdps/assault_10_fs30/consolidated_gorp_bounds.json
#   inflating: bridge_dataset/mdps/assault_10_fs30/consolidated.npz
#   inflating: bridge_dataset/mdps/assault_10_fs30/gorp_7.json
#   inflating: bridge_dataset/mdps/assault_10_fs30/consolidated_analyzed.json
#   inflating: bridge_dataset/mdps/assault_10_fs30/gorp_1.json
#    creating: bridge_dataset/mdps/MiniGrid-ObstructedMaze-1Dlh-v0/
#   inflating: bridge_dataset/mdps/MiniGrid-ObstructedMaze-1Dlh-v0/gorp_3.json
#   inflating: bridge_dataset/mdps/MiniGrid-ObstructedMaze-1Dlh-v0/gorp_5.json
#   inflating: bridge_dataset/mdps/MiniGrid-ObstructedMaze-1Dlh-v0/gorp_2.json
#   inflating: bridge_dataset/mdps/MiniGrid-ObstructedMaze-1Dlh-v0/gorp_4.json
#   inflating: bridge_dataset/mdps/MiniGrid-ObstructedMaze-1Dlh-v0/consolidated_gorp_bounds.json
#   inflating: bridge_dataset/mdps/MiniGrid-ObstructedMaze-1Dlh-v0/consolidated.npz
#   inflating: bridge_dataset/mdps/MiniGrid-ObstructedMaze-1Dlh-v0/consolidated_analyzed.json
#   inflating: bridge_dataset/mdps/MiniGrid-ObstructedMaze-1Dlh-v0/gorp_1.json
#    creating: bridge_dataset/mdps/jumper_easy_l1_20_fs8/
#   inflating: bridge_dataset/mdps/jumper_easy_l1_20_fs8/gorp_3.json
#   inflating: bridge_dataset/mdps/jumper_easy_l1_20_fs8/gorp_5.json
#   inflating: bridge_dataset/mdps/jumper_easy_l1_20_fs8/gorp_2.json
#   inflating: bridge_dataset/mdps/jumper_easy_l1_20_fs8/gorp_4.json
#   inflating: bridge_dataset/mdps/jumper_easy_l1_20_fs8/consolidated_gorp_bounds.json
#   inflating: bridge_dataset/mdps/jumper_easy_l1_20_fs8/consolidated.npz
#   inflating: bridge_dataset/mdps/jumper_easy_l1_20_fs8/consolidated_analyzed.json
#   inflating: bridge_dataset/mdps/jumper_easy_l1_20_fs8/gorp_1.json
#    creating: bridge_dataset/mdps/freeway_20_fs30/
#   inflating: bridge_dataset/mdps/freeway_20_fs30/gorp_3.json
#   inflating: bridge_dataset/mdps/freeway_20_fs30/gorp_6.json
#   inflating: bridge_dataset/mdps/freeway_20_fs30/gorp_5.json
#   inflating: bridge_dataset/mdps/freeway_20_fs30/gorp_11.json
#   inflating: bridge_dataset/mdps/freeway_20_fs30/gorp_2.json
#   inflating: bridge_dataset/mdps/freeway_20_fs30/gorp_4.json
#   inflating: bridge_dataset/mdps/freeway_20_fs30/gorp_8.json
#   inflating: bridge_dataset/mdps/freeway_20_fs30/gorp_9.json
#   inflating: bridge_dataset/mdps/freeway_20_fs30/consolidated_gorp_bounds.json
#   inflating: bridge_dataset/mdps/freeway_20_fs30/consolidated.npz
#   inflating: bridge_dataset/mdps/freeway_20_fs30/gorp_7.json
#   inflating: bridge_dataset/mdps/freeway_20_fs30/consolidated_analyzed.json
#   inflating: bridge_dataset/mdps/freeway_20_fs30/gorp_1.json
#   inflating: bridge_dataset/mdps/freeway_20_fs30/gorp_10.json
#    creating: bridge_dataset/mdps/MiniGrid-DoorKey-8x8-v0/
#   inflating: bridge_dataset/mdps/MiniGrid-DoorKey-8x8-v0/gorp_3.json
#   inflating: bridge_dataset/mdps/MiniGrid-DoorKey-8x8-v0/gorp_5.json
#   inflating: bridge_dataset/mdps/MiniGrid-DoorKey-8x8-v0/gorp_2.json
#   inflating: bridge_dataset/mdps/MiniGrid-DoorKey-8x8-v0/gorp_4.json
#   inflating: bridge_dataset/mdps/MiniGrid-DoorKey-8x8-v0/consolidated_gorp_bounds.json
#   inflating: bridge_dataset/mdps/MiniGrid-DoorKey-8x8-v0/consolidated.npz
#   inflating: bridge_dataset/mdps/MiniGrid-DoorKey-8x8-v0/consolidated_analyzed.json
#   inflating: bridge_dataset/mdps
consolidated_analyzed.json
#   inflating: bridge_dataset/mdps/breakout_70_fs30/gorp_1.json
#    creating: bridge_dataset/mdps/maze_exploration_l0_100_fs1/
#   inflating: bridge_dataset/mdps/maze_exploration_l0_100_fs1/gorp_3.json
#   inflating: bridge_dataset/mdps/maze_exploration_l0_100_fs1/gorp_2.json
#   inflating: bridge_dataset/mdps/maze_exploration_l0_100_fs1/gorp_4.json
#   inflating: bridge_dataset/mdps/maze_exploration_l0_100_fs1/consolidated_gorp_bounds.json
#   inflating: bridge_dataset/mdps/maze_exploration_l0_100_fs1/consolidated.npz
#   inflating: bridge_dataset/mdps/maze_exploration_l0_100_fs1/consolidated_analyzed.json
#   inflating: bridge_dataset/mdps/maze_exploration_l0_100_fs1/gorp_1.json
#    creating: bridge_dataset/mdps/chaser_easy_l1_20_fs2/
#   inflating: bridge_dataset/mdps/chaser_easy_l1_20_fs2/gorp_3.json
#   inflating: bridge_dataset/mdps/chaser_easy_l1_20_fs2/gorp_5.json
#   inflating: bridge_dataset/mdps/chaser_easy_l1_20_fs2/gorp_2.json
#   inflating: bridge_dataset/mdps/chaser_easy_l1_20_fs2/gorp_4.json
#   inflating: bridge_dataset/mdps/chaser_easy_l1_20_fs2/consolidated_gorp_bounds.json
#   inflating: bridge_dataset/mdps/chaser_easy_l1_20_fs2/consolidated.npz
#   inflating: bridge_dataset/mdps/chaser_easy_l1_20_fs2/consolidated_analyzed.json
#   inflating: bridge_dataset/mdps/chaser_easy_l1_20_fs2/gorp_1.json
#    creating: bridge_dataset/mdps/MiniGrid-KeyCorridorS3R2-v0/
#   inflating: bridge_dataset/mdps/MiniGrid-KeyCorridorS3R2-v0/gorp_3.json
#   inflating: bridge_dataset/mdps/MiniGrid-KeyCorridorS3R2-v0/gorp_5.json
#   inflating: bridge_dataset/mdps/MiniGrid-KeyCorridorS3R2-v0/gorp_2.json
#   inflating: bridge_dataset/mdps/MiniGrid-KeyCorridorS3R2-v0/gorp_4.json
#   inflating: bridge_dataset/mdps/MiniGrid-KeyCorridorS3R2-v0/consolidated_gorp_bounds.json
#   inflating: bridge_dataset/mdps/MiniGrid-KeyCorridorS3R2-v0/consolidated.npz
#   inflating: bridge_dataset/mdps/MiniGrid-KeyCorridorS3R2-v0/consolidated_analyzed.json
#   inflating: bridge_dataset/mdps/MiniGrid-KeyCorridorS3R2-v0/gorp_1.json
#    creating: bridge_dataset/mdps/enduro_10_fs30/
#   inflating: bridge_dataset/mdps/enduro_10_fs30/gorp_3.json
#   inflating: bridge_dataset/mdps/enduro_10_fs30/gorp_6.json
#   inflating: bridge_dataset/mdps/enduro_10_fs30/gorp_5.json
#   inflating: bridge_dataset/mdps/enduro_10_fs30/gorp_2.json
#   inflating: bridge_dataset/mdps/enduro_10_fs30/gorp_4.json
#   inflating: bridge_dataset/mdps/enduro_10_fs30/consolidated_gorp_bounds.json
#   inflating: bridge_dataset/mdps/enduro_10_fs30/consolidated.npz
#   inflating: bridge_dataset/mdps/enduro_10_fs30/gorp_7.json
#   inflating: bridge_dataset/mdps/enduro_10_fs30/consolidated_analyzed.json
#   inflating: bridge_dataset/mdps/enduro_10_fs30/gorp_1.json

# %% [markdown]
# ## Making BRIDGE Environments

# %%
# imports
import gym

# %%
# making environment from the BRIDGE dataset
def make_environment(type, version_num, rom="pong", horizon="50", frameskip="30", game="coinrun", difficulty="easy", level="10", env="Empty-5x5"):
    allowed_types = ["Atari","Procgen","Minigrid"]
    if type == "Atari":
        return gym.make(f"BRIDGE/{rom}_{horizon}_fs{frameskip}-v{version_num}")
    elif type == "Procgen":
        return gym.make(f"BRIDGE/{game}_{difficulty}_l{level}_{horizon}_fs{frameskip}-v{version_num}")
    elif type == "Minigrid":
        return gym.make(f"BRIDGE/MiniGrid_{env}-v{version_num}")
    else:
        raise(ValueError("Input 'type' must be one of: {}".format(allowed_types)))

# %%
make_environment("Atari", )

# %% [markdown]
# ## Deep RL Training

# %%
# imports
import multiprocessing
import os
from datetime import datetime
from logging import Logger
from typing import Callable, Dict, Optional, Any, cast

import cloudpickle
import numpy as np
import ray
import torch
from ray.rllib.algorithms import Algorithm
from ray.rllib.policy.sample_batch import DEFAULT_POLICY_ID
from ray.tune.logger import UnifiedLogger
from ray.tune.registry import ENV_CREATOR, _global_registry, get_trainable_cls
from ray.rllib.utils.typing import PolicyID
from ray.rllib.policy.policy import Policy
from ray.rllib.evaluation.worker_set import WorkerSet
from sacred import SETTINGS as sacred_settings
from sacred import Experiment

ex = Experiment("train")
sacred_settings.CONFIG.READ_ONLY_CONFIG = False

torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.allow_tf32 = True

# %%
# utils to use
def build_logger_creator(log_dir: str, experiment_name: str):
    experiment_dir = os.path.join(
        log_dir,
        experiment_name,
        datetime.now().strftime("%Y-%m-%d_%H-%M-%S"),
    )

    def custom_logger_creator(config):
        """
        Creates a Unified logger that stores results in
        <log_dir>/<experiment_name>_<timestamp>
        """

        if not os.path.exists(experiment_dir):
            os.makedirs(experiment_dir, exist_ok=True)
        return UnifiedLogger(config, experiment_dir)

    return custom_logger_creator


def load_policies_from_checkpoint(
    checkpoint_fname: str,
    trainer: Algorithm,
    policy_map: Callable[[PolicyID], PolicyID] = lambda policy_id: policy_id,
):
    """
    Load policy model weights from a checkpoint and copy them into the given
    trainer.
    """

    with open(checkpoint_fname, "rb") as checkpoint_file:
        checkpoint_data = cloudpickle.load(checkpoint_file)
    policy_states: Dict[str, Any] = cloudpickle.loads(checkpoint_data["worker"])[
        "state"
    ]

    policy_weights = {
        policy_map(policy_id): policy_state["weights"]
        for policy_id, policy_state in policy_states.items()
    }

    def copy_policy_weights(policy: Policy, policy_id: PolicyID):
        if policy_id in policy_weights:
            policy.set_weights(policy_weights[policy_id])

    workers: WorkerSet = cast(Any, trainer).workers
    workers.foreach_policy(copy_policy_weights)

# %%
# train function
def train(
    config,
    log_dir,
    experiment_name,
    run,
    num_training_iters,
    stop_on_timesteps: Optional[int],
    stop_on_eval_reward: Optional[float],
    stop_on_kl: Optional[float],
    save_freq,
    checkpoint_path: Optional[str],
    checkpoint_to_load_policies: Optional[str],
    _log: Logger,
):
    multiprocessing.set_start_method("spawn")
    ray.init(
        ignore_reinit_error=True,
        include_dashboard=False,
    )

    AlgorithmClass = get_trainable_cls(run)
    trainer: Algorithm = AlgorithmClass(
        config,
        logger_creator=build_logger_creator(
            log_dir,
            experiment_name,
        ),
    )

    if checkpoint_to_load_policies is not None:
        _log.info(f"Initializing policies from {checkpoint_to_load_policies}")
        load_policies_from_checkpoint(checkpoint_to_load_policies, trainer)

    if checkpoint_path is not None:
        _log.info(f"Restoring checkpoint at {checkpoint_path}")
        trainer.restore(checkpoint_path)

    num_iters_below_kl = 0

    result = None
    for train_iter in range(num_training_iters):
        _log.info(f"Starting training iteration {trainer.iteration}")
        result = trainer.train()

        if trainer.iteration % save_freq == 0:
            checkpoint = trainer.save()
            _log.info(f"Saved checkpoint to {checkpoint}")

        if stop_on_eval_reward is not None:
            if (
                result["evaluation"]["episode_reward_mean"]
                >= stop_on_eval_reward - 1e-4
            ):
                break
        if stop_on_kl is not None:
            kl = result["info"]["learner"][DEFAULT_POLICY_ID]["learner_stats"].get(
                "kl", np.inf
            )
            if kl < stop_on_kl:
                num_iters_below_kl += 1
            else:
                num_iters_below_kl = 0
            if num_iters_below_kl >= 10:
                break
        if stop_on_timesteps is not None:
            if result["timesteps_total"] >= stop_on_timesteps:
                break

        episode_lengths = result["sampler_results"]["hist_stats"]["episode_lengths"]
        if len(episode_lengths) > 0:
            max_episode_len = max(episode_lengths)
            if run == "GORP" and trainer.iteration > max_episode_len:
                break

    checkpoint = trainer.save()
    _log.info(f"Saved final checkpoint to {checkpoint}")

    # Symlink final checkpoint to checkpoint_final
    os.symlink(
        os.path.basename(checkpoint),
        os.path.join(os.path.dirname(checkpoint), "checkpoint_final"),
    )

    return result

# %% [markdown]
# ## Get Tabular MDP Representations -> Get the consolidated.npz file

# %%
# imports
from dataclasses import dataclass, field
from typing import Union

# %%
# utils
@dataclass
class MDPConfig:
    horizon: int
    log_dir: Union[str, None] = None
    done_on_reward: bool = False
    no_done_reward: float = 0.0
    noops_after_horizon: int = 0
    frameskip: int = 5
    num_workers: int = 1

@dataclass
class AtariMDPConfig(MDPConfig):
    rom_file: str
    done_on_life_lost: bool

@dataclass
class MiniGridMDPConfig(MDPConfig):
    env_name: str

@dataclass
class ProcgenMDPConfig(MDPConfig):
    env_name: str
    level: int = 0
    distribution_mode: str

@dataclass
class AtariEnv:
    ale: ALE
    lives: int
    config: AtariMDPConfig
    life_lost: bool

    def __post_init__(self):
        # Set ALE configurations
        self.ale.set_logger_mode('error')
        self.ale.set_int('random_seed', 0)
        self.ale.set_int('system_random_seed', 4753849)
        self.ale.set_float('repeat_action_probability', 0)

        # Load ROM and reset the game
        self.ale.load_rom(self.config.rom_file)
        self.ale.reset_game()

        # Retrieve initial number of lives
        self.lives = self.ale.lives()

# Function to create an instance of AtariEnv
def get_env(config):
    return AtariEnv(ale=ALE(), lives=0, config=config, life_lost=False)

# %%
def setup_tabular_configs(type, type_args):
    allowed_types = ["Atari","Procgen","Minigrid"]
    try:
        if type == "Atari":
            return AtariMDPConfig(
                rom_file = type_args["rom"],
                horizon = type_args["horizon"],
                done_on_reward = type_args["done_on_reward"],
                done_on_life_lost = type_args["done_on_life_lost"],
                no_done_reward = type_args["no_done_reward"],
                noops_after_horizon = type_args["noops_after_horizon"],
                frameskip = type_args["frameskip"],
                log_dir = type_args["out"])
        elif type == "Procgen":
            return ProcgenMDPConfig(
                env_name = type_args["env_name"],
                distribution_mode = type_args["distribution_mode"],
                level = type_args["level"],
                horizon = type_args["horizon"],
                done_on_reward = type_args["done_on_reward"],
                no_done_reward = type_args["no_done_reward"],
                noops_after_horizon = type_args["noops_after_horizon"],
                frameskip = type_args["frameskip"],
                log_dir = type_args["out"])
        elif type == "Minigrid":
            return MiniGridMDPConfig(
                env_name = type_args["env_name"],
                horizon = type_args["horizon"],
                done_on_reward = type_args["done_on_reward"],
                no_done_reward = type_args["no_done_reward"],
                noops_after_horizon = type_args["noops_after_horizon"],
                frameskip = type_args["frameskip"],
                log_dir = type_args["out"])
        else:
            raise(ValueError("Input 'type' must be one of: {}".format(allowed_types)))
    except:
        raise(ValueError("Input 'type_args' dictionary does not contain all necessary values."))


# TODO
def construct_mdp(mdp_config):
    # get env by input config type
    if isinstance(mdp_config, AtariMDPConfig):
        env = AtariEnv(ale=ALE(), lives=0, config=mdp_config, life_lost=False)
    elif isinstance(mdp_config, MiniGridMDPConfig):
        pass
    elif isinstance(mdp_config, ProcgenMDPConfig):
        pass
    else:
        raise ValueError("Input 'mdp_config' type is not one of the handled types.")
    pass

def get_tabular_reps(type, type_args):
    # setup configuration struct based on inputs
    config = setup_tabular_configs(type, type_args)
    # construct the MDP
    mdp = construct_mdp(config)
    # get the npz file

    pass

# %% [markdown]
# ## Get complexity bounds (EPW and EH)

# %% [markdown]
# ## Instance

# %%
# setup env of interest spec (constants)

# %% [markdown]
# # Current

# %% [markdown]
# ## Construct environments

# %%
# imports
import gym

from minigrid.core.grid import Grid
from minigrid.core.world_object import Box, Door, Goal, Lava, WorldObj
from minigrid.envs.blockedunlockpickup import BlockedUnlockPickupEnv
from minigrid.envs.keycorridor import KeyCorridorEnv
from minigrid.envs.obstructedmaze import ObstructedMazeEnv
from minigrid.envs.unlockpickup import UnlockPickupEnv
from minigrid.minigrid_env import MiniGridEnv
from minigrid.wrappers import FlatObsWrapper, FullyObsWrapper
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 6
#       4 from minigrid.core.grid import Grid
#       5 from minigrid.core.world_object import Box, Door, Goal, Lava, WorldObj
# ----> 6 from minigrid.envs.blockedunlockpickup import BlockedUnlockPickupEnv
#       7 from minigrid.envs.keycorridor import KeyCorridorEnv
#       8 from minigrid.envs.obstructedmaze import ObstructedMazeEnv
#
# File /opt/anaconda3/envs/EH/lib/python3.9/site-packages/minigrid/__init__.py:5
#       1 from __future__ import annotations
#       3 from gymnasium.envs.registration import register
# ----> 5 from minigrid import minigrid_env, wrappers
#       6 from minigrid.core import roomgrid
#       7 from minigrid.core.world_object import Wall
#
# File /opt/anaconda3/envs/EH/lib/python3.9/site-packages/minigrid/minigrid_env.py:8
#       5 from abc import abstractmethod
#       6 from typing import Any, Iterable, SupportsFloat, TypeVar
# ----> 8 import gymnasium as gym
#       9 import numpy as np
#      10 import pygame
#
# File /opt/anaconda3/envs/EH/lib/python3.9/site-packages/gymnasium/__init__.py:14
#       6 from gymnasium.core import (
#       7     Env,
#       8     Wrapper,
#    (...)
#      11     RewardWrapper,
#      12 )
#      13 from gymnasium.spaces import Space
# ---> 14 from gymnasium.envs import make, spec, register
#      15 from gymnasium import logger
#      16 from gymnasium import vector
#
# File /opt/anaconda3/envs/EH/lib/python3.9/site-packages/gymnasium/envs/__init__.py:5
#       2 from gymnasium.envs.registration import make, register, registry, spec
#       4 # Hook to load plugins from entry points
# ----> 5 _load_env_plugins()
#       8 # Classic
#       9 # ----------------------------------------
#      11 register(
#      12     id="CartPole-v0",
#      13     entry_point="gymnasium.envs.classic_control.cartpole:CartPoleEnv",
#      14     max_episode_steps=200,
#      15     reward_threshold=195.0,
#      16 )
#
# File /opt/anaconda3/envs/EH/lib/python3.9/site-packages/gymnasium/envs/registration.py:305, in load_env_plugins(entry_point)
#     299         logger.warn(
#     300             f"The environment namespace magic key `{plugin.name}` is unsupported. "
#     301             "To register an environment at the root namespace you should specify the `__root__` namespace."
#     302         )
#     304 with context:
# --> 305     fn = plugin.load()
#     306     try:
#     307         fn()
#
# File /opt/anaconda3/envs/EH/lib/python3.9/site-packages/importlib_metadata/__init__.py:184, in EntryPoint.load(self)
#     179 """Load the entry point from its definition. If only a module
#     180 is indicated by the value, return that module. Otherwise,
#     181 return the named object.
#     182 """
#     183 match = self.pattern.match(self.value)
# --> 184 module = import_module(match.group('module'))
#     185 attrs = filter(None, (match.group('attr') or '').split('.'))
#     186 return functools.reduce(getattr, attrs, module)
#
# File /opt/anaconda3/envs/EH/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File /opt/anaconda3/envs/EH/lib/python3.9/site-packages/minigrid/__init__.py:6
#       3 from gymnasium.envs.registration import register
#       5 from minigrid import minigrid_env, wrappers
# ----> 6 from minigrid.core import roomgrid
#       7 from minigrid.core.world_object import Wall
#       9 __version__ = "2.2.1"
#
# File /opt/anaconda3/envs/EH/lib/python3.9/site-packages/minigrid/core/roomgrid.py:8
#       6 from minigrid.core.grid import Grid
#       7 from minigrid.core.world_object import Ball, Box, Door, Key, WorldObj
# ----> 8 from minigrid.minigrid_env import MiniGridEnv
#      11 def reject_next_to(env: MiniGridEnv, pos: tuple[int, int]):
#      12     """
#      13     Function to filter out object positions that are right next to
#      14     the agent's starting point
#      15     """
#
# ImportError: cannot import name 'MiniGridEnv' from partially initialized module 'minigrid.minigrid_env' (most likely due to a circular import) (/opt/anaconda3/envs/EH/lib/python3.9/site-packages/minigrid/minigrid_env.py)

# %%
def make_gym_environment(type, version_num, rom="pong", horizon="50", frameskip="30", game="coinrun", difficulty="easy", level="10", env="Empty-5x5"):
    allowed_types = ["Atari","Procgen","Minigrid"]
    if type == "Atari":
        return gym.make(f"BRIDGE/{rom}_{horizon}_fs{frameskip}-v{version_num}")
    elif type == "Procgen":
        return gym.make(f"BRIDGE/{game}_{difficulty}_l{level}_{horizon}_fs{frameskip}-v{version_num}")
    elif type == "Minigrid":
        return gym.make(f"BRIDGE/MiniGrid_{env}-v{version_num}")
    else:
        raise(ValueError("Input 'type' must be one of: {}".format(allowed_types)))

# %%
# %pip install minigrid
# Out:
# Requirement already satisfied: minigrid in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (2.2.1)
# Requirement already satisfied: numpy>=1.18.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from minigrid) (1.20.3)
# Requirement already satisfied: gymnasium>=0.26 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from minigrid) (0.26.3)
# Requirement already satisfied: pygame>=2.2.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from minigrid) (2.5.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from gymnasium>=0.26->minigrid) (3.0.0)
# Requirement already satisfied: gymnasium-notices>=0.0.1 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from gymnasium>=0.26->minigrid) (0.0.1)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from gymnasium>=0.26->minigrid) (6.8.0)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/envs/EH/lib/python3.9/site-packages (from importlib-metadata>=4.8.0->gymnasium>=0.26->minigrid) (3.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python deterministic_registration.py
# Out:
# Traceback (most recent call last):
#   File "/Users/laurenc/Documents/GitHub/282_expansion/scripts/deterministic_registration.py", line 9, in <module>
#     import gymnasium as gym
#   File "/opt/anaconda3/envs/EH/lib/python3.9/site-packages/gymnasium/__init__.py", line 14, in <module>
#     from gymnasium.envs import make, spec, register
#   File "/opt/anaconda3/envs/EH/lib/python3.9/site-packages/gymnasium/envs/__init__.py", line 5, in <module>
#     _load_env_plugins()
#   File "/opt/anaconda3/envs/EH/lib/python3.9/site-packages/gymnasium/envs/registration.py", line 305, in load_env_plugins
#     fn = plugin.load()
#   File "/opt/anaconda3/envs/EH/lib/python3.9/site-packages/importlib_metadata/__init__.py", line 184, in load
#     module = import_module(match.group('module'))
#   File "/opt/anaconda3/envs/EH/lib/python3.9/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/laurenc/Documents/GitHub/282_expansion/scripts/minigrid.py", line 7, in <module>
#     from minigrid.core.grid import Grid
# ModuleNotFoundError: No module named 'minigrid.core'; 'minigrid' is not a package

# %%
env = make_gym_environment("Atari", 0)
# Out:
# ---------------------------------------------------------------------------
# NamespaceNotFound                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 env = make_gym_environment("Atari", 0)
#
# Cell In[15], line 4, in make_gym_environment(type, version_num, rom, horizon, frameskip, game, difficulty, level, env)
#       2 allowed_types = ["Atari","Procgen","Minigrid"]
#       3 if type == "Atari":
# ----> 4     return gym.make(f"BRIDGE/{rom}_{horizon}_fs{frameskip}-v{version_num}")
#       5 elif type == "Procgen":
#       6     return gym.make(f"BRIDGE/{game}_{difficulty}_l{level}_{horizon}_fs{frameskip}-v{version_num}")
#
# File /opt/anaconda3/envs/EH/lib/python3.9/site-packages/gym/envs/registration.py:569, in make(id, max_episode_steps, autoreset, apply_api_compatibility, disable_env_checker, **kwargs)
#     563         logger.warn(
#     564             f"Using the latest versioned environment `{new_env_id}` "
#     565             f"instead of the unversioned environment `{id}`."
#     566         )
#     568     if spec_ is None:
# --> 569         _check_version_exists(ns, name, version)
#     570         raise error.Error(f"No registered env with id: {id}")
#     572 _kwargs = spec_.kwargs.copy()
#
# File /opt/anaconda3/envs/EH/lib/python3.9/site-packages/gym/envs/registration.py:219, in _check_version_exists(ns, name, version)
#     216 if get_env_id(ns, name, version) in registry:
#     217     return
# --> 219 _check_name_exists(ns, name)
#     220 if version is None:
#     221     return
#
# File /opt/anaconda3/envs/EH/lib/python3.9/site-packages/gym/envs/registration.py:187, in _check_name_exists(ns, name)
#     185 def _check_name_exists(ns: Optional[str], name: str):
#     186     """Check if an env exists in a namespace. If it doesn't, print a helpful error message."""
# --> 187     _check_namespace_exists(ns)
#     188     names = {spec_.name for spec_ in registry.values() if spec_.namespace == ns}
#     190     if name in names:
#
# File /opt/anaconda3/envs/EH/lib/python3.9/site-packages/gym/envs/registration.py:182, in _check_namespace_exists(ns)
#     173 suggestion = (
#     174     difflib.get_close_matches(ns, namespaces, n=1) if len(namespaces) > 0 else None
#     175 )
#     176 suggestion_msg = (
#     177     f"Did you mean: `{suggestion[0]}`?"
#     178     if suggestion
#     179     else f"Have you installed the proper package for {ns}?"
#     180 )
# --> 182 raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
#
# NamespaceNotFound: Namespace BRIDGE not found. Have you installed the proper package for BRIDGE?
